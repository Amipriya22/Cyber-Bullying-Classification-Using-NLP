# %% [markdown]
# # All questions are worth 2 marks.
# ## Create a copy of this notebook using the "copy and edit" option and solve the questions. Use the "Save version" option on top right and save the final submission as rollno._firstname.

# %%
#read about the details of the given dataset from this link :
#https://www.kaggle.com/competitions/widsdatathon2023/data 

#import this dataset in this notebook by copying the path of the dataset that is already added in the Data
#section and then putting that path in the pd.read_csv() function 

#your code
import pandas as pd

data = "/kaggle/input/widsdatathon2023/test_data.csv"
df = pd.read_csv(data)
df
# Out:
#         index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333   11/1/22                              339.88
# 1      375735  0.0  0.833333   11/2/22                              334.63
# 2      375736  0.0  0.833333   11/3/22                              337.83
# 3      375737  0.0  0.833333   11/4/22                              345.81
# 4      375738  0.0  0.833333   11/5/22                              357.39
# ...       ...  ...       ...       ...                                 ...
# 31349  407083  1.0  0.866667  12/27/22                               62.72
# 31350  407084  1.0  0.866667  12/28/22                               73.41
# 31351  407085  1.0  0.866667  12/29/22                               70.00
# 31352  407086  1.0  0.866667  12/30/22                               79.81
# 31353  407087  1.0  0.866667  12/31/22                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# ...

# %%
#separate out the target column 'contest-tmp2m-14d__tmp2m' from the dataset and name it as target. 
#also delete this column from the original column

#your code

import pandas as pd
data = "/kaggle/input/widsdatathon2023/train_data.csv"
df = pd.read_csv(data)
target = df['contest-tmp2m-14d__tmp2m']
df.drop('contest-tmp2m-14d__tmp2m', axis=1, inplace=True)
print(target)
# Out:
# 0         28.744480
# 1         28.370585
# 2         28.133059
# 3         28.256798
# 4         28.372353
#             ...
# 375729    17.150954
# 375730    16.962051
# 375731    16.915474
# 375732    16.536761
# 375733    15.910995
# Name: contest-tmp2m-14d__tmp2m, Length: 375734, dtype: float64

# %%
#there is a column that has date, separate the dates in day, month and year and make 3 separate columns
#for them.

#your code
import pandas as pd
data="/kaggle/input/widsdatathon2023/test_data.csv"
df=pd.read_csv(data)
df['startdate'] = pd.to_datetime(df['startdate'])
df['day'] = df['startdate'].dt.day
df['month'] = df['startdate'].dt.month
df['year'] = df['startdate'].dt.year
print(df)
# Out:
#         index  lat       lon  startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333 2022-11-01                              339.88
# 1      375735  0.0  0.833333 2022-11-02                              334.63
# 2      375736  0.0  0.833333 2022-11-03                              337.83
# 3      375737  0.0  0.833333 2022-11-04                              345.81
# 4      375738  0.0  0.833333 2022-11-05                              357.39
# ...       ...  ...       ...        ...                                 ...
# 31349  407083  1.0  0.866667 2022-12-27                               62.72
# 31350  407084  1.0  0.866667 2022-12-28                               73.41
# 31351  407085  1.0  0.866667 2022-12-29                               70.00
# 31352  407086  1.0  0.866667 2022-12-30                               79.81
# 31353  407087  1.0  0.866667 2022-12-31                               86.17
#
# ...

# %%
#I want you to go to column number 58, it has values like: 'BSh', 'Cfa', 'BSk'. See how many unique such
#values are there and replace each one of them with a number.


#your code
import pandas as pd
data = "/kaggle/input/widsdatathon2023/test_data.csv"
df = pd.read_csv(data)
column_99 = df.iloc[:, 98]
unique_values = column_99.unique()
mapping = {value: i for i, value in enumerate(unique_values)}
column_99_replaced = column_99.replace(mapping)
num_unique_values = len(unique_values)
print("Number of unique values:", num_unique_values)
df.iloc[:, 98] = column_99_replaced
print(df)
# Out:
# Number of unique values: 15
#         index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333   11/1/22                              339.88
# 1      375735  0.0  0.833333   11/2/22                              334.63
# 2      375736  0.0  0.833333   11/3/22                              337.83
# 3      375737  0.0  0.833333   11/4/22                              345.81
# 4      375738  0.0  0.833333   11/5/22                              357.39
# ...       ...  ...       ...       ...                                 ...
# 31349  407083  1.0  0.866667  12/27/22                               62.72
# 31350  407084  1.0  0.866667  12/28/22                               73.41
# 31351  407085  1.0  0.866667  12/29/22                               70.00
# 31352  407086  1.0  0.866667  12/30/22                               79.81
# 31353  407087  1.0  0.866667  12/31/22                               86.17
#
# ...

# %%
#there are various columns like nmme0-tmp2m-34w__cancm30,nmme0-tmp2m-34w__cancm40, etc.
#these columns contain most recent monthly NMME model forecasts for various models.
#find out how many such columns exist(fron the dataset link I have posted above)
#calculate the mean of all the values of these columns and fill them in a new row 'mean'.

#your code
import pandas as pd
data="/kaggle/input/widsdatathon2023/test_data.csv"
df = pd.read_csv(data) 
target = [col for col in df.columns if col.startswith('nmme0-tmp2m-34w__')]
num = len(target)
mean = df[target].mean()
df = df.append(pd.Series(mean, name='mean'))
print(df)
# Out:
#           index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734.0  0.0  0.833333   11/1/22                              339.88
# 1      375735.0  0.0  0.833333   11/2/22                              334.63
# 2      375736.0  0.0  0.833333   11/3/22                              337.83
# 3      375737.0  0.0  0.833333   11/4/22                              345.81
# 4      375738.0  0.0  0.833333   11/5/22                              357.39
# ...         ...  ...       ...       ...                                 ...
# 31350  407084.0  1.0  0.866667  12/28/22                               73.41
# 31351  407085.0  1.0  0.866667  12/29/22                               70.00
# 31352  407086.0  1.0  0.866667  12/30/22                               79.81
# 31353  407087.0  1.0  0.866667  12/31/22                               86.17
# mean        NaN  NaN       NaN       NaN                                 NaN
#
# ...
